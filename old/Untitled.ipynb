# %%
import ee
import geemap
import folium

# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project = "ee-samettenborough")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def create_aoi(coordinates):
  aoi = ee.Geometry.Polygon(coordinates)
  return aoi

# Split the AOI into tiles
def create_tiles(aoi, grid_size_km):
    grid_size_degrees = grid_size_km / 111.32  # Approximation for latitude
    bounds = aoi.bounds().getInfo()["coordinates"][0]
    min_x, min_y = bounds[0]
    max_x, max_y = bounds[2]

    tiles = []
    x = min_x
    while x < max_x:
        y = min_y
        while y < max_y:
            chunk = ee.Geometry.Rectangle([
                x,
                y,
                min(x + grid_size_degrees, max_x),
                min(y + grid_size_degrees, max_y)
            ])
            tiles.append(chunk)
            y += grid_size_degrees
        x += grid_size_degrees

    return tiles
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
fire_1 = [[-90.1517107831, 15.5726233568],
       [-89.1726311637, 15.5726233568],
       [-89.1726311637, 16.29215598],
       [-90.1517107831, 16.29215598],
       [-90.1517107831, 15.5726233568]
          ]

aoi = create_aoi(fire_1)
tiles = create_tiles(aoi, 25)

# Create a folium map centered on Guatemala
m = folium.Map(location=[15.9, -89.6], zoom_start=8)

# Add each tile to the map
for i, tile in enumerate(tiles):
    # Get the bounds of the tile (latitude and longitude)
    bounds = tile.bounds().getInfo()["coordinates"][0]

    # Create a polygon for the tile
    folium.Polygon(
        locations=[(lat, lon) for lon, lat in bounds],
        color="blue",  # Border color
        fill=True,
        fill_color="blue",
        fill_opacity=0.2,
        weight=2
    ).add_to(m)

# Display the map
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c343c4fc7cc5c52d25a3bc02cf63a059 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c343c4fc7cc5c52d25a3bc02cf63a059&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c343c4fc7cc5c52d25a3bc02cf63a059 = L.map(
#                 &quot;map_c343c4fc7cc5c52d25a3bc02cf63a059&quot;,
#                 {
#                     center: [15.9, -89.6],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f71c04976c940d2896d285d14ae8e1ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f71c04976c940d2896d285d14ae8e1ee.addTo(map_c343c4fc7cc5c52d25a3bc02cf63a059);
#
#
#             var polygon_ce41042a8839aa9a8a395f3c4a629998 = L.polygon(
#                 [[15.57262335679995, -90.1517107831], [15.57262335679995, -89.92713298935224], [15.797229973752719, -89.92713298935224], [15.797229973752719, -90.1517107831], [15.57262335679995, -90.1517107831]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c343c4fc7cc5c52d25a3bc02cf63a059);
#
#
#             var polygon_d727ab98e81d76e5cf5f779228ceddb5 = L.polygon(
#                 [[15.797201150547702, -90.1517107831], [15.797201150547702, -89.92713298935224], [16.021808133971316, -89.92713298935224], [16.021808133971316, -90.1517107831], [15.797201150547702, -90.1517107831]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c343c4fc7cc5c52d25a3bc02cf63a059);
#
#
#             var polygon_aa8947ed2c2bad0435727c4c53bed80f = L.polygon(
#                 [[16.02177894429546, -90.1517107831], [16.02177894429546, -89.92713298935224], [16.246386292396107, -89.92713298935224], [16.246386292396107, -90.1517107831], [16.02177894429546, -90.1517107831]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c343c4fc7cc5c52d25a3bc02cf63a059);
#
#
#             var polygon_74dce2471cfb49365e20462b9f24c14c = L.polygon(
#                 [[16.246356738043215, -90.1517107831], [16.246356738043215, -89.92713298935224], [16.29274875853333, -89.92713298935224], [16.29274875853333, -90.1517107831], [16.246356738043215, -90.1517107831]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c343c4fc7cc5c52d25a3bc02cf63a059);
#
#
#             var polygon_a1404fde82a1eea7dcfa8c29425fe2da = L.polygon(
#                 [[15.57262335679995, -89.92713298935224], [15.57262335679995, -89.70255519560449], [15.797229973752724, -89.70255519560449], [15.797229973752724, -89.92713298935224], [15.57262335679995, -89.92713298935224]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&

# %%
# Initialize map centered on AOI
m = folium.Map(location=[15.9, -89.6], zoom_start=8)

# Add AOI boundary to map
aoi = ee.Geometry.Polygon(fire_1)
folium.GeoJson(aoi.getInfo()).add_to(m)

# Display the map
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d39f48a7b0c8246a01285ded24a33fd4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d39f48a7b0c8246a01285ded24a33fd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d39f48a7b0c8246a01285ded24a33fd4 = L.map(
#                 &quot;map_d39f48a7b0c8246a01285ded24a33fd4&quot;,
#                 {
#                     center: [15.9, -89.6],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cccffe18d517b6c4d505eb965773a6c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cccffe18d517b6c4d505eb965773a6c1.addTo(map_d39f48a7b0c8246a01285ded24a33fd4);
#
#
#
#         function geo_json_c741a4d042686536893c2ec0721c0632_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c741a4d042686536893c2ec0721c0632 = L.geoJson(null, {
#                 onEachFeature: geo_json_c741a4d042686536893c2ec0721c0632_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_c741a4d042686536893c2ec0721c0632_add (data) {
#             geo_json_c741a4d042686536893c2ec0721c0632
#                 .addData(data);
#         }
#             geo_json_c741a4d042686536893c2ec0721c0632_add({&quot;coordinates&quot;: [[[-90.1517107831, 15.5726233568], [-89.1726311637, 15.5726233568], [-89.1726311637, 16.29215598], [-90.1517107831, 16.29215598], [-90.1517107831, 15.5726233568]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_c741a4d042686536893c2ec0721c0632.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_c741a4d042686536893c2ec0721c0632.addTo(map_d39f48a7b0c8246a01285ded24a33fd4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Define the country boundary (Guatemala)
guat = ee.FeatureCollection("FAO/GAUL/2015/level0") \
    .filter(ee.Filter.eq('ADM0_NAME', 'Guatemala')) \
    .geometry()

Map = geemap.Map()
Map.addLayer(guat, {}, "Guatemala")
Map.centerObject(guat, 7)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[15.692016609691928, -90.35759919897927], controls=(WidgetControl(options=['position', 'transparent…

# %%
# landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1")\
#     .filterDate("2024-01-01", "2024-02-01")\
#     .filterBounds(guat)

landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1")
filtered = (
    landsat.filterBounds(guat)
    .filterDate('2023-09-01', '2024-02-01')
    .sort("CLOUD_COVER")
)
    
Map.addLayer(landsat, {}, "Landsat")
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[15.692016609691928, -90.35759919897927], controls=(WidgetControl(options=['position', 'transparent…

# %%
composite = ee.Algorithms.Landsat.simpleComposite(**{
    'collection': landsat,
    'asFloat': True
})

rgbVis = {'bands': ['B4', 'B3', 'B2'],
          'min': 0,
          'max': 0.3
         }

Map.addLayer(composite.clip(guat), rgbVis, "Landsat")
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[15.692016609691928, -90.35759919897927], controls=(WidgetControl(options=['position', 'transparent…

# %%
landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")
filtered = (
    landsat.filterBounds(guat)
    .filterDate('2023-09-01', '2024-02-01')
    .sort("CLOUD_COVER")
)
    
# Mask clouds using the QA_PIXEL band
def mask_clouds(image):
    # QA_PIXEL: Bit 5 = Cloud, Bit 7 = Cloud Shadow
    qa = image.select('QA_PIXEL')
    cloud_mask = qa.bitwiseAnd(1 << 5).eq(0)  # Cloud bit
    shadow_mask = qa.bitwiseAnd(1 << 7).eq(0)  # Cloud shadow bit
    return image.updateMask(cloud_mask.And(shadow_mask))

# Apply cloud masking and filter
filtered = (
    landsat.filterBounds(guat)
    .filterDate('2023-09-01', '2024-02-01')
    .map(mask_clouds)
)

# Create a median composite
composite = filtered.median()

# Visualization parameters
rgb_vis = {
    'bands': ['SR_B4', 'SR_B3', 'SR_B2'],  # Red, Green, Blue bands
    'min': 0,
    'max': 20000,
}

Map.addLayer(composite.clip(guat), rgb_vis, "Landsat Composite")
Map
